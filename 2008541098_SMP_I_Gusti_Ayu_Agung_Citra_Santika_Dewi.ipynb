# %%
# Diketahui x memenuhi x^2+x-1=0
# Menentukan nilai dari n yang memenuhi : x^2024-x^2025 = (x(1-x))^n


import math

# Nilai dari persamaan kuadrat :
a_98 = 1
b_98 = 1
c_98 = -1

# Menghitung nilai dari akar-akar persamaan kuadrat
x1_98 = (-b + math.sqrt(b**2 - 4*a*c)) / (2*a)
x2_98 = (-b - math.sqrt(b**2 - 4*a*c)) / (2*a)

print('Akar-akar persamaan kuadrat:')
print('x1 =', x1_98)
print('x2 =', x2_98)

# Memilih salah satu akarnya yaitu x1, untuk menghitung nilai x^2024 - x^2025 :
x_98 = x1_98

# Dimana nilai dari persamaan kuadrat x^2+x-1=0 ini, yaitu x^2 = 1-x
nilai_x_kuadrat_98 = 1-x

# Menggunakan Logaritma untuk Menemukan Nilai 𝑛
# Dimana x^2024-x^2025 = (x(1-x))^n
#        x1^2024 * (1-x1) = (x1 * (1-x1))^n
#        log * (x1^2024 * (1-x1)) = log * ((x1 * (1-x1))^n) 
#        2024log(x1 ) + log(1−x1) = n * (log(x1) + log(1-x1))
#        n = 2024log(x1) + log(1-x1) / log(x1)+ log(1-x1)

# Menghitung nilai logaritma
logaritma_x_98 = math.log(x_98)
log_nilai_x_kuadrat_98 = math.log(nilai_x_kuadrat_98)

# Menghitung nilai n
n_98 = (2024 * logaritma_x_98 + log_nilai_x_kuadrat_98) / (logaritma_x_98 + log_nilai_x_kuadrat_98)

print('Nilai n yang memenuhi persamaan tersebut adalah:', n_98)
# Out:
# Akar-akar persamaan kuadrat:
# x1 = 0.6180339887498949
# x2 = -1.618033988749895
# Nilai n yang memenuhi persamaan tersebut adalah: 675.3333333333331
